# %% [markdown]
# ## Importing the Necessary Packages

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Input, Add, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D, AveragePooling2D, MaxPooling2D, Conv3D, GlobalMaxPooling2D
from tensorflow.keras.initializers import glorot_uniform
from tensorflow.keras.models import Model, load_model
from tensorflow.keras import layers
from tensorflow.keras.layers import Input


import numpy as np
import matplotlib.pyplot as plt
from astropy.table import Table
from astropy.io import fits
from PIL import Image

from skimage.transform import resize

# %%
import keras
from keras.layers import Input, Add, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D, AveragePooling2D, MaxPooling2D, Conv3D, GlobalMaxPooling2D
from keras.initializers import glorot_uniform
from keras.models import Model, load_model
from keras import layers
from keras.layers import Input

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import regularizers
from tensorflow.keras import optimizers
# Keras Layers
from keras.layers import InputLayer
from keras.layers import Conv2D
from keras.layers import BatchNormalization
from keras.layers import Dropout
from keras.layers import MaxPool2D
from keras.layers import Flatten
from keras.layers import Dense

# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession
config = ConfigProto()
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)
# Out:
# 2023-02-16 19:05:26.062085: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-02-16 19:05:26.093198: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-16 19:05:26.096797: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-16 19:05:26.096899: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-16 19:05:26.420795: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-16 19:05:26.420946: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-16 19:05:26.421105: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-16 19:05:26.421274: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 3530 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1660 SUPER, pci bus id: 0000:01:00.0, compute capability: 7.5

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
import scikitplot as skplt
from sklearn.metrics import plot_roc_curve
from sklearn.metrics import roc_curve
from sklearn.metrics import RocCurveDisplay
from sklearn.metrics import auc
from sklearn.metrics import roc_auc_score

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))   ### Checking for GPU
# Out:
# Num GPUs Available:  1
# 2023-02-16 19:05:26.459756: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-16 19:05:26.459895: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-16 19:05:26.459988: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero

# %%
tf.config.list_physical_devices('GPU') ### Checking for GPU
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ### DATA

# %%
# Load the training data from a FITS file (replace '..........' with the actual file path)
# The image data should be in (g,r,z) format and have a size of 64*64

data = Table.read(r'........../training_data.fits')

# Extract the 'IMAGE' feature for the first 35,000 records (training data)
X = np.array(data['IMAGE'][:35000])

# Extract the 'Class' labels for the first 35,000 records (training data)
Y = np.array(data['Class'][:35000])

# Extract 'IMAGE' values for validation data (records 35,000 to 37,500)
X_Val = np.array(data['IMAGE'][35000:37500])

# Extract 'Class' labels for validation data (records 35,000 to 37,500)
Y_Val = np.array(data['Class'][35000:37500])

# Prepare 'IMAGE' values for the test data (starting from record 37,500)
X_test = np.array(data['IMAGE'][37500:])

# Prepare 'Class' labels for the test data (starting from record 37,500)
Y_test = np.array(data['Class'][37500:])

# %% [markdown]
# ### Visualising the Training data

# %%
# Illustration of a lens in the 4 bands provided
def Image_plot():
    c = input('Please enter the Id of the Galaxy that you need to see')
    im = X[int(c)]
    plt.subplot(221)
    plt.imshow(im[:,:,0],vmin=0, vmax = 15); plt.colorbar()
    plt.subplot(222)
    plt.imshow(im[:,:,1],vmin=0, vmax = 15); plt.colorbar()
    plt.subplot(223) 
    plt.imshow(im[:,:,2],vmin=0, vmax = 15); plt.colorbar()
    plt.show()

    if Y[int(c)] == 1:
        print('The above galaxis is an LSB')
    else:
        print('The above image is an artifact')
    mu = -2.5*np.log10(15) + 30 + 2.5*np.log10(0.263**2)
    print('Image plotted with a threshold magnitude of ',mu)

# %%
Image_plot()
# Out:
# Please enter the Id of the Galaxy that you need to see4
# The above image is an artifact
# Image plotted with a threshold magnitude of  24.159550594809588

# %% [markdown]
# ### Data Augmnetation

# %%
# Create an ImageDataGenerator with horizontal and vertical flipping enabled
datagen = tf.keras.preprocessing.image.ImageDataGenerator(horizontal_flip=True, vertical_flip=True)

# Fit the data generator to the training data (X). This computes the required statistics.
datagen.fit(X)

# Fit the data generator to the validation data (X_Val). This ensures consistent data transformations.
datagen.fit(X_Val)

# %% [markdown]
# ## LSBG DETR Model

# %% [markdown]
# #### Positional Encoding

# %%
# The get_angles function calculates angle rates for each position in the sequence.
def get_angles(pos, i, d_model):
    angle_rates = 1 / np.power(12800, (2 * (i // 2)) / np.float64(d_model))
    return pos * angle_rates

# The positional_encoding function generates positional encodings for a given position and d_model.
def positional_encoding(position, d_model):
    # Calculate angle radians using the get_angles function for each position and feature.
    angle_rads = get_angles(np.arange(position)[:, np.newaxis],
                          np.arange(d_model)[np.newaxis, :],
                          d_model)

    # Apply the sine function to even indices (2i) and cosine function to odd indices (2i+1).
    angle_rads[0::2, :] = np.sin(angle_rads[0::2, :])
    angle_rads[1::2, :] = np.cos(angle_rads[1::2, :])

    # Create the final positional encoding array by adding an extra dimension.
    pos_encoding = angle_rads[np.newaxis]

    # Cast the positional encoding to the desired data type (tf.float64 in this case).
    return tf.cast(pos_encoding, dtype=tf.float64)

# %% [markdown]
# #### Transformer

# %%
d_model = 128
maximum_position_encoding = 10000
scaling_factor = tf.keras.backend.constant(np.sqrt(d_model), shape = (1,1,1))

# Define the model architecture
# Encoder ##################################
input_shape = (64,64,3)
inputs=Input(shape=(input_shape),name='input_layer')

x = Conv2D(filters=16, kernel_size=(3, 3), strides=(1, 1), padding='valid',activation='elu', kernel_initializer=glorot_uniform(seed=0),kernel_regularizer=tf.keras.regularizers.l2(0.01), name='Conv1' )(inputs)
x = BatchNormalization(axis=3)(x)
x = Conv2D(filters=16, kernel_size=(3, 3), strides=(1, 1), padding='valid',activation='elu', kernel_initializer=glorot_uniform(seed=0),kernel_regularizer=tf.keras.regularizers.l2(0.01), name='Conv2' )(x)
x = MaxPooling2D((2, 2),name='max1')(x)
x = BatchNormalization(axis=3)(x)

x = Conv2D(filters=32, kernel_size=(3, 3), strides=(1, 1), padding='valid',activation='elu', kernel_initializer=glorot_uniform(seed=0),kernel_regularizer=tf.keras.regularizers.l2(0.01),name='Conv3')(x)
x = BatchNormalization(axis=3)(x)
x = Conv2D(filters=32, kernel_size=(3, 3), strides=(1, 1), padding='valid',activation='elu', kernel_initializer=glorot_uniform(seed=0),kernel_regularizer=tf.keras.regularizers.l2(0.01),name='Conv4')(x)
x = MaxPooling2D((2, 2),name='max2')(x)
x = BatchNormalization(axis=3)(x)

x = Conv2D(filters=64, kernel_size=(3, 3), strides=(1, 1), padding='valid',activation='elu', kernel_initializer=glorot_uniform(seed=0),kernel_regularizer=tf.keras.regularizers.l2(0.01),name='Conv5')(x)
x = BatchNormalization(axis=3)(x)
x = layers.Dropout(0.6)(x)
x = Conv2D(filters=64, kernel_size=(3, 3), strides=(1, 1), padding='valid',activation='elu', kernel_initializer=glorot_uniform(seed=0),kernel_regularizer=tf.keras.regularizers.l2(0.01),name='Conv6')(x)
x = BatchNormalization(axis=3)(x)
x = layers.Dropout(0.6)(x)

x = Conv2D(filters=128, kernel_size=(3, 3), strides=(1, 1), padding='valid',activation='elu', kernel_initializer=glorot_uniform(seed=0),kernel_regularizer=tf.keras.regularizers.l2(0.01),name='Conv7')(x)
x = BatchNormalization(axis=3)(x)
x = layers.Dropout(0.6)(x)
x = Conv2D(filters=128, kernel_size=(3, 3), strides=(1, 1), padding='valid',activation='elu', kernel_initializer=glorot_uniform(seed=0),kernel_regularizer=tf.keras.regularizers.l2(0.01),name='Conv8')(x)
x = BatchNormalization(axis=3)(x)
x = layers.Dropout(0.6)(x)


x= tf.reshape(tensor=x, shape=(tf.shape(x)[0], tf.shape(x)[1]*tf.shape(x)[2],d_model))

## positional encoding
x = tf.keras.layers.Multiply()([x,scaling_factor])
pos = positional_encoding(maximum_position_encoding, d_model)
x = tf.keras.layers.Add()([x, pos[: , :tf.shape(x)[1], :]] )

## Multihead Attention 1

x1 = tf.keras.layers.MultiHeadAttention(num_heads=8, key_dim=d_model, value_dim=d_model, dropout=0.20, use_bias=True, kernel_initializer='glorot_uniform', kernel_regularizer=tf.keras.regularizers.l2(0.01))(x,x)
x2 = tf.keras.layers.MultiHeadAttention(num_heads=8, key_dim=d_model, value_dim=d_model, dropout=0.20, use_bias=True, kernel_initializer='glorot_uniform', kernel_regularizer=tf.keras.regularizers.l2(0.01))(x,x)

x = tf.keras.layers.Add()([x1, x2]) 

x3 = tf.keras.layers.MultiHeadAttention(num_heads=8, key_dim=d_model, value_dim=d_model, dropout=0.20, use_bias=True, kernel_initializer='glorot_uniform', kernel_regularizer=tf.keras.regularizers.l2(0.01))(x,x)
x4 = tf.keras.layers.MultiHeadAttention(num_heads=8, key_dim=d_model, value_dim=d_model, dropout=0.20, use_bias=True, kernel_initializer='glorot_uniform', kernel_regularizer=tf.keras.regularizers.l2(0.01))(x,x)

x = tf.keras.layers.Add()([x3, x4]) 

## Feed Forward 1
dense =  Dense(2*d_model, activation = 'elu',kernel_initializer="glorot_uniform",name='dense1')(x)
dense = layers.Dropout(0.6)(dense)
dense =  Dense(d_model, activation = 'elu',kernel_initializer="glorot_uniform",name='dense2')(dense)
dense = layers.Dropout(0.6)(dense)
x = tf.keras.layers.Add()([x , dense])                                          # residual connection
x = tf.keras.layers.LayerNormalization(epsilon=1e-6)(x)

######################################################

x = tf.keras.layers.GlobalAveragePooling1D()(x)

######################################################


x =  Dense(1024, activation = 'elu',kernel_initializer="glorot_uniform",name='dense4')(x)
x = layers.Dropout(0.6)(x)

x =  Dense(512, activation = 'elu',kernel_initializer="glorot_uniform",name='dense5')(x)
x = layers.Dropout(0.6)(x)

x =  Dense(128, activation = 'elu',kernel_initializer="glorot_uniform",name='dense6')(x)
x = layers.Dropout(0.6)(x)

output = layers.Dense(1, activation="sigmoid")(x)

LSBG_Detector = tf.keras.models.Model(inputs=inputs, outputs=output)

lr_schedule1 = tf.keras.optimizers.schedules.ExponentialDecay(initial_learning_rate=1e-4,decay_steps=10000,decay_rate=0.9)
opt1=tf.keras.optimizers.Adam(learning_rate=lr_schedule1, beta_1=0.9, beta_2=0.999, epsilon=1e-07)

LSBG_Detector.compile(optimizer=opt1, loss='binary_crossentropy', metrics=['accuracy',tf.keras.metrics.AUC()])
# Out:
# 2023-02-16 19:06:01.208256: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-16 19:06:01.208410: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-16 19:06:01.208509: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-16 19:06:01.208642: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-16 19:06:01.208744: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-16 19:06:01.208818: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 3530 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1660 SUPER, pci bus id: 0000:01:00.0, compute capability: 7.5

# %%
LSBG_Detector.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_layer (InputLayer)       [(None, 64, 64, 3)]  0           []
#
#  Conv1 (Conv2D)                 (None, 62, 62, 16)   448         ['input_layer[0][0]']
#
#  batch_normalization (BatchNorm  (None, 62, 62, 16)  64          ['Conv1[0][0]']
#  alization)
#
#  Conv2 (Conv2D)                 (None, 60, 60, 16)   2320        ['batch_normalization[0][0]']
#
#  max1 (MaxPooling2D)            (None, 30, 30, 16)   0           ['Conv2[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 30, 30, 16)  64          ['max1[0][0]']
#  rmalization)
#
#  Conv3 (Conv2D)                 (None, 28, 28, 32)   4640        ['batch_normalization_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 28, 28, 32)  128         ['Conv3[0][0]']
#  rmalization)
#
#  Conv4 (Conv2D)                 (None, 26, 26, 32)   9248        ['batch_normalization_2[0][0]']
#
#  max2 (MaxPooling2D)            (None, 13, 13, 32)   0           ['Conv4[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 13, 13, 32)  128         ['max2[0][0]']
#  rmalization)
#
#  Conv5 (Conv2D)                 (None, 11, 11, 64)   18496       ['batch_normalization_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 11, 11, 64)  256         ['Conv5[0][0]']
#  rmalization)
#
#  dropout (Dropout)              (None, 11, 11, 64)   0           ['batch_normalization_4[0][0]']
#
#  Conv6 (Conv2D)                 (None, 9, 9, 64)     36928       ['dropout[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 9, 9, 64)    256         ['Conv6[0][0]']
#  rmalization)
#
#  dropout_1 (Dropout)            (None, 9, 9, 64)     0           ['batch_normalization_5[0][0]']
#
#  Conv7 (Conv2D)                 (None, 7, 7, 128)    73856       ['dropout_1[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 7, 7, 128)   512         ['Conv7[0][0]']
#  rmalization)
#
#  dropout_2 (Dropout)            (None, 7, 7, 128)    0           ['batch_normalization_6[0][0]']
#
#  Conv8 (Conv2D)                 (None, 5, 5, 128)    147584      ['dropout_2[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 5, 5, 128)   512         ['Conv8[0][0]']
#  rmalization)
#
#  dropout_3 (Dropout)            (None, 5, 5, 128)    0           ['batch_normalization_7[0][0]']
#
#  tf.compat.v1.shape_1 (TFOpLamb  (4,)                0           ['dropout_3[0][0]']
#  da)
#
#  tf.compat.v1.shape_2 (TFOpLamb  (4,)                0           ['dropout_3[0][0]']
#  da)
#
#  tf.compat.v1.shape (TFOpLambda  (4,)                0           ['dropout_3[0][0]']
#  )
#
#  tf.__operators__.getitem_1 (Sl  ()                  0           ['tf.compat.v1.shape_1[0][0]']
#  icingOpLambda)
#
#  tf.__operators__.getitem_2 (Sl  ()                  0           ['tf.compat.v1.shape_2[0][0]']
#  icingOpLambda)
#
#  tf.__operators__.getitem (Slic  ()                  0           ['tf.compat.v1.shape[0][0]']
#  ingOpLambda)
#
#  tf.math.multiply (TFOpLambda)  ()                   0           ['tf.__operators__.getitem_1[0][0
#                                                                  ]',
#                                                                   'tf.__operators__.getitem_2[0][0
#                                                                  ]']
#
#  tf.reshape (TFOpLambda)        (None, 25, 128)      0           ['dropout_3[0][0]',
#                                                                   'tf.__operators__.getitem[0][0]'
#                                                                  , 'tf.math.multiply[0][0]']
#
#  multiply (Multiply)            (None, 25, 128)      0           ['tf.reshape[0][0]']
#
#  tf.compat.v1.shape_3 (TFOpLamb  (3,)                0           ['multiply[0][0]']
#  da)
#
#  tf.__operators__.getitem_3 (Sl  ()                  0           ['tf.compat.v1.shape_3[0][0]']
#  icingOpLambda)
#
#  tf.stack (TFOpLambda)          (3,)                 0           ['tf.__operators__.getitem_3[0][0
#                                                                  ]']
#
#  tf.strided_slice (TFOpLambda)  (1, 25, 128)         0           ['tf.stack[0][0]']
#
#  add (Add)                      (None, 25, 128)      0           ['multiply[0][0]',
#                                                                   'tf.strided_slice[0][0]']
#
#  multi_head_attention (MultiHea  (None, 25, 128)     527488      ['add[0][0]',
#  dAttention)                                                      'add[0][0]']
#
#  multi_head_attention_1 (MultiH  (None, 25, 128)     527488      ['add[0][0]',
#  eadAttention)                                                    'add[0][0]']
#
#  add_1 (Add)                    (None, 25, 128)      0           ['multi_head_attention[0][0]',
#                                                                   'multi_head_attention_1[0][0]']
#
#  multi_head_attention_2 (MultiH  (None, 25, 128)     527488      ['add_1[0][0]',
#  eadAttention)                                                    'add_1[0][0]']
#
#  multi_head_attention_3 (MultiH  (None, 25, 128)     527488      ['add_1[0][0]',
#  eadAttention)                                                    'add_1[0][0]']
#
#  add_2 (Add)                    (None, 25, 128)      0           ['multi_head_attention_2[0][0]',
#                                                                   'multi_head_attention_3[0][0]']
#
#  dense1 (Dense)                 (None, 25, 256)      33024       ['add_2[0][0]']
#
#  dropout_4 (Dropout)            (None, 25, 256)      0           ['dense1[0][0]']
#
#  dense2 (Dense)                 (None, 25, 128)      32896       ['dropout_4[0][0]']
#
#  dropout_5 (Dropout)            (None, 25, 128)      0           ['dense2[0][0]']
#
#  add_3 (Add)                    (None, 25, 128)      0           ['add_2[0][0]',
#                                                                   'dropout_5[0][0]']
#
#  layer_normalization (LayerNorm  (None, 25, 128)     256         ['add_3[0][0]']
#  alization)
#
#  global_average_pooling1d (Glob  (None, 128)         0           ['layer_normalization[0][0]']
#  alAveragePooling1D)
#
#  dense4 (Dense)                 (None, 1024)         132096      ['global_average_pooling1d[0][0]'
#                                                                  ]
#
#  dropout_6 (Dropout)            (None, 1024)         0           ['dense4[0][0]']
#
#  dense5 (Dense)                 (None, 512)          524800      ['dropout_6[0][0]']
#
#  dropout_7 (Dropout)            (None, 512)          0           ['dense5[0][0]']
#
#  dense6 (Dense)                 (None, 128)          65664       ['dropout_7[0][0]']
#
#  dropout_8 (Dropout)            (None, 128)          0           ['dense6[0][0]']
#
#  dense (Dense)                  (None, 1)            129         ['dropout_8[0][0]']
#
# ==================================================================================================
# Total params: 3,194,257
# Trainable params: 3,193,297
# Non-trainable params: 960
# __________________________________________________________________________________________________

# %%
e_stop = tf.keras.callbacks.EarlyStopping(monitor='val_loss',min_delta=0,patience=20,verbose=1,mode='auto',baseline=None,restore_best_weights=True)

# %% [markdown]
# ## Training the LSBG DETR Model

# %%
LSBG_Detector.fit(datagen.flow(X,Y),epochs=5,validation_data=datagen.flow(X_Val,Y_Val),batch_size=128,verbose=1,callbacks=e_stop,shuffle=True) #Training the network with 10% of training
# Out:
# Epoch 1/5
# 2023-02-16 19:06:07.668118: I tensorflow/stream_executor/cuda/cuda_dnn.cc:368] Loaded cuDNN version 8100
# 1094/1094 [==============================] - 24s 19ms/step - loss: 8.2271 - accuracy: 0.7640 - auc: 0.8184 - val_loss: 5.4913 - val_accuracy: 0.7944 - val_auc: 0.8869
# Epoch 2/5
# 1094/1094 [==============================] - 20s 18ms/step - loss: 3.7522 - accuracy: 0.8211 - auc: 0.8714 - val_loss: 3.2202 - val_accuracy: 0.7408 - val_auc: 0.8928
# Epoch 3/5
# 1094/1094 [==============================] - 20s 18ms/step - loss: 2.0165 - accuracy: 0.8395 - auc: 0.8911 - val_loss: 1.7584 - val_accuracy: 0.7716 - val_auc: 0.9113
# Epoch 4/5
# 1094/1094 [==============================] - 20s 18ms/step - loss: 1.3126 - accuracy: 0.8641 - auc: 0.9181 - val_loss: 2.0075 - val_accuracy: 0.6252 - val_auc: 0.8669
# Epoch 5/5
# 1094/1094 [==============================] - 20s 18ms/step - loss: 1.0001 - accuracy: 0.8801 - auc: 0.9341 - val_loss: 1.0500 - val_accuracy: 0.8864 - val_auc: 0.9435

# %%
LSBG_history = LSBG_Detector.fit(datagen.flow(X,Y),epochs=200,validation_data=datagen.flow(X_Val,Y_Val),batch_size=128,verbose=1,callbacks=e_stop,shuffle=True) #Training the network with 10% of training
# Out:
# Epoch 1/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.8329 - accuracy: 0.8963 - auc: 0.9463 - val_loss: 0.7995 - val_accuracy: 0.9076 - val_auc: 0.9601
# Epoch 2/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.7255 - accuracy: 0.9038 - auc: 0.9507 - val_loss: 0.7311 - val_accuracy: 0.8772 - val_auc: 0.9583
# Epoch 3/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.6411 - accuracy: 0.9037 - auc: 0.9543 - val_loss: 0.6923 - val_accuracy: 0.9196 - val_auc: 0.9560
# Epoch 4/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.5742 - accuracy: 0.9112 - auc: 0.9554 - val_loss: 0.6575 - val_accuracy: 0.9092 - val_auc: 0.9541
# Epoch 5/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.5193 - accuracy: 0.9114 - auc: 0.9582 - val_loss: 0.6172 - val_accuracy: 0.9220 - val_auc: 0.9533
# Epoch 6/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.4776 - accuracy: 0.9131 - auc: 0.9589 - val_loss: 0.5329 - val_accuracy: 0.9252 - val_auc: 0.9606
# Epoch 7/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.4410 - accuracy: 0.9157 - auc: 0.9600 - val_loss: 0.4651 - val_accuracy: 0.9128 - val_auc: 0.9612
# Epoch 8/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.4151 - accuracy: 0.9186 - auc: 0.9611 - val_loss: 0.4871 - val_accuracy: 0.9280 - val_auc: 0.9601
# Epoch 9/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.3921 - accuracy: 0.9180 - auc: 0.9620 - val_loss: 0.4475 - val_accuracy: 0.9284 - val_auc: 0.9637
# Epoch 10/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.3765 - accuracy: 0.9191 - auc: 0.9618 - val_loss: 0.4396 - val_accuracy: 0.9280 - val_auc: 0.9618
# Epoch 11/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.3629 - accuracy: 0.9204 - auc: 0.9629 - val_loss: 0.4298 - val_accuracy: 0.9300 - val_auc: 0.9599
# Epoch 12/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.3523 - accuracy: 0.9194 - auc: 0.9634 - val_loss: 0.4373 - val_accuracy: 0.9236 - val_auc: 0.9603
# Epoch 13/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.3434 - accuracy: 0.9225 - auc: 0.9631 - val_loss: 0.4091 - val_accuracy: 0.9308 - val_auc: 0.9629
# Epoch 14/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.3344 - accuracy: 0.9220 - auc: 0.9648 - val_loss: 0.3611 - val_accuracy: 0.9192 - val_auc: 0.9676
# Epoch 15/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.3244 - accuracy: 0.9215 - auc: 0.9646 - val_loss: 0.3846 - val_accuracy: 0.9276 - val_auc: 0.9614
# Epoch 16/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.3194 - accuracy: 0.9231 - auc: 0.9643 - val_loss: 0.5502 - val_accuracy: 0.8140 - val_auc: 0.9632
# Epoch 17/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.3130 - accuracy: 0.9241 - auc: 0.9654 - val_loss: 0.3411 - val_accuracy: 0.9288 - val_auc: 0.9669
# Epoch 18/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.3111 - accuracy: 0.9237 - auc: 0.9641 - val_loss: 0.3823 - val_accuracy: 0.8808 - val_auc: 0.9665
# Epoch 19/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.3020 - accuracy: 0.9253 - auc: 0.9667 - val_loss: 0.3795 - val_accuracy: 0.8768 - val_auc: 0.9652
# Epoch 20/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2974 - accuracy: 0.9257 - auc: 0.9659 - val_loss: 0.3233 - val_accuracy: 0.9320 - val_auc: 0.9675
# Epoch 21/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2938 - accuracy: 0.9259 - auc: 0.9674 - val_loss: 0.3066 - val_accuracy: 0.9320 - val_auc: 0.9716
# Epoch 22/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2925 - accuracy: 0.9265 - auc: 0.9675 - val_loss: 0.3235 - val_accuracy: 0.9136 - val_auc: 0.9710
# Epoch 23/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2844 - accuracy: 0.9273 - auc: 0.9687 - val_loss: 0.2889 - val_accuracy: 0.9340 - val_auc: 0.9697
# Epoch 24/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2881 - accuracy: 0.9263 - auc: 0.9684 - val_loss: 0.3213 - val_accuracy: 0.9188 - val_auc: 0.9654
# Epoch 25/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2860 - accuracy: 0.9261 - auc: 0.9675 - val_loss: 0.3159 - val_accuracy: 0.9332 - val_auc: 0.9679
# Epoch 26/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2801 - accuracy: 0.9265 - auc: 0.9688 - val_loss: 0.2908 - val_accuracy: 0.9276 - val_auc: 0.9690
# Epoch 27/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2818 - accuracy: 0.9263 - auc: 0.9680 - val_loss: 0.2950 - val_accuracy: 0.9324 - val_auc: 0.9719
# Epoch 28/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2787 - accuracy: 0.9270 - auc: 0.9686 - val_loss: 0.3069 - val_accuracy: 0.9108 - val_auc: 0.9692
# Epoch 29/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2730 - accuracy: 0.9279 - auc: 0.9695 - val_loss: 0.2863 - val_accuracy: 0.9284 - val_auc: 0.9691
# Epoch 30/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2767 - accuracy: 0.9287 - auc: 0.9688 - val_loss: 0.3260 - val_accuracy: 0.9080 - val_auc: 0.9683
# Epoch 31/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2725 - accuracy: 0.9277 - auc: 0.9691 - val_loss: 0.2912 - val_accuracy: 0.9264 - val_auc: 0.9711
# Epoch 32/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2694 - accuracy: 0.9276 - auc: 0.9701 - val_loss: 0.2898 - val_accuracy: 0.9300 - val_auc: 0.9715
# Epoch 33/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2682 - accuracy: 0.9285 - auc: 0.9702 - val_loss: 0.2980 - val_accuracy: 0.9228 - val_auc: 0.9686
# Epoch 34/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2647 - accuracy: 0.9276 - auc: 0.9708 - val_loss: 0.2845 - val_accuracy: 0.9308 - val_auc: 0.9701
# Epoch 35/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2624 - accuracy: 0.9283 - auc: 0.9712 - val_loss: 0.2890 - val_accuracy: 0.9208 - val_auc: 0.9708
# Epoch 36/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2655 - accuracy: 0.9291 - auc: 0.9694 - val_loss: 0.2763 - val_accuracy: 0.9332 - val_auc: 0.9716
# Epoch 37/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2648 - accuracy: 0.9282 - auc: 0.9705 - val_loss: 0.2706 - val_accuracy: 0.9328 - val_auc: 0.9710
# Epoch 38/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2577 - accuracy: 0.9298 - auc: 0.9716 - val_loss: 0.2629 - val_accuracy: 0.9340 - val_auc: 0.9723
# Epoch 39/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2568 - accuracy: 0.9296 - auc: 0.9711 - val_loss: 0.2720 - val_accuracy: 0.9292 - val_auc: 0.9726
# Epoch 40/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2604 - accuracy: 0.9295 - auc: 0.9702 - val_loss: 0.2892 - val_accuracy: 0.9264 - val_auc: 0.9700
# Epoch 41/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2564 - accuracy: 0.9282 - auc: 0.9714 - val_loss: 0.3016 - val_accuracy: 0.9036 - val_auc: 0.9732
# Epoch 42/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2553 - accuracy: 0.9296 - auc: 0.9711 - val_loss: 0.2624 - val_accuracy: 0.9320 - val_auc: 0.9726
# Epoch 43/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2540 - accuracy: 0.9301 - auc: 0.9713 - val_loss: 0.2750 - val_accuracy: 0.9268 - val_auc: 0.9715
# Epoch 44/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2542 - accuracy: 0.9293 - auc: 0.9719 - val_loss: 0.3024 - val_accuracy: 0.9308 - val_auc: 0.9671
# Epoch 45/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2532 - accuracy: 0.9295 - auc: 0.9714 - val_loss: 0.2603 - val_accuracy: 0.9272 - val_auc: 0.9726
# Epoch 46/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2525 - accuracy: 0.9305 - auc: 0.9714 - val_loss: 0.2602 - val_accuracy: 0.9324 - val_auc: 0.9728
# Epoch 47/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2503 - accuracy: 0.9311 - auc: 0.9720 - val_loss: 0.4127 - val_accuracy: 0.8656 - val_auc: 0.9686
# Epoch 48/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2498 - accuracy: 0.9300 - auc: 0.9719 - val_loss: 0.2709 - val_accuracy: 0.9332 - val_auc: 0.9719
# Epoch 49/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2494 - accuracy: 0.9315 - auc: 0.9723 - val_loss: 0.2703 - val_accuracy: 0.9336 - val_auc: 0.9724
# Epoch 50/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2472 - accuracy: 0.9313 - auc: 0.9719 - val_loss: 0.2705 - val_accuracy: 0.9248 - val_auc: 0.9694
# Epoch 51/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2478 - accuracy: 0.9300 - auc: 0.9724 - val_loss: 0.2592 - val_accuracy: 0.9292 - val_auc: 0.9719
# Epoch 52/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2461 - accuracy: 0.9299 - auc: 0.9726 - val_loss: 0.2783 - val_accuracy: 0.9132 - val_auc: 0.9735
# Epoch 53/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2512 - accuracy: 0.9306 - auc: 0.9714 - val_loss: 0.2621 - val_accuracy: 0.9320 - val_auc: 0.9717
# Epoch 54/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2430 - accuracy: 0.9313 - auc: 0.9726 - val_loss: 0.2622 - val_accuracy: 0.9292 - val_auc: 0.9727
# Epoch 55/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2407 - accuracy: 0.9328 - auc: 0.9728 - val_loss: 0.2723 - val_accuracy: 0.9328 - val_auc: 0.9719
# Epoch 56/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2421 - accuracy: 0.9308 - auc: 0.9725 - val_loss: 0.2557 - val_accuracy: 0.9272 - val_auc: 0.9714
# Epoch 57/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2424 - accuracy: 0.9303 - auc: 0.9723 - val_loss: 0.2442 - val_accuracy: 0.9340 - val_auc: 0.9746
# Epoch 58/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2401 - accuracy: 0.9317 - auc: 0.9732 - val_loss: 0.2536 - val_accuracy: 0.9356 - val_auc: 0.9735
# Epoch 59/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2405 - accuracy: 0.9306 - auc: 0.9729 - val_loss: 0.2598 - val_accuracy: 0.9320 - val_auc: 0.9721
# Epoch 60/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2377 - accuracy: 0.9315 - auc: 0.9732 - val_loss: 0.2494 - val_accuracy: 0.9292 - val_auc: 0.9724
# Epoch 61/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2403 - accuracy: 0.9310 - auc: 0.9725 - val_loss: 0.2543 - val_accuracy: 0.9356 - val_auc: 0.9736
# Epoch 62/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2366 - accuracy: 0.9324 - auc: 0.9740 - val_loss: 0.2515 - val_accuracy: 0.9336 - val_auc: 0.9716
# Epoch 63/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2391 - accuracy: 0.9323 - auc: 0.9727 - val_loss: 0.2733 - val_accuracy: 0.9260 - val_auc: 0.9718
# Epoch 64/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2347 - accuracy: 0.9324 - auc: 0.9742 - val_loss: 0.2519 - val_accuracy: 0.9356 - val_auc: 0.9736
# Epoch 65/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2362 - accuracy: 0.9328 - auc: 0.9734 - val_loss: 0.2453 - val_accuracy: 0.9312 - val_auc: 0.9736
# Epoch 66/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2340 - accuracy: 0.9316 - auc: 0.9741 - val_loss: 0.2712 - val_accuracy: 0.9184 - val_auc: 0.9724
# Epoch 67/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2330 - accuracy: 0.9330 - auc: 0.9743 - val_loss: 0.2531 - val_accuracy: 0.9260 - val_auc: 0.9739
# Epoch 68/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2326 - accuracy: 0.9335 - auc: 0.9741 - val_loss: 0.2558 - val_accuracy: 0.9288 - val_auc: 0.9731
# Epoch 69/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2341 - accuracy: 0.9309 - auc: 0.9738 - val_loss: 0.2438 - val_accuracy: 0.9364 - val_auc: 0.9742
# Epoch 70/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2344 - accuracy: 0.9329 - auc: 0.9733 - val_loss: 0.3217 - val_accuracy: 0.9012 - val_auc: 0.9715
# Epoch 71/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2306 - accuracy: 0.9334 - auc: 0.9742 - val_loss: 0.2372 - val_accuracy: 0.9384 - val_auc: 0.9745
# Epoch 72/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2309 - accuracy: 0.9331 - auc: 0.9744 - val_loss: 0.2483 - val_accuracy: 0.9316 - val_auc: 0.9744
# Epoch 73/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2287 - accuracy: 0.9338 - auc: 0.9746 - val_loss: 0.2453 - val_accuracy: 0.9300 - val_auc: 0.9744
# Epoch 74/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2305 - accuracy: 0.9330 - auc: 0.9739 - val_loss: 0.2605 - val_accuracy: 0.9248 - val_auc: 0.9713
# Epoch 75/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2272 - accuracy: 0.9351 - auc: 0.9747 - val_loss: 0.2693 - val_accuracy: 0.9288 - val_auc: 0.9709
# Epoch 76/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2274 - accuracy: 0.9343 - auc: 0.9745 - val_loss: 0.2605 - val_accuracy: 0.9292 - val_auc: 0.9725
# Epoch 77/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2269 - accuracy: 0.9338 - auc: 0.9753 - val_loss: 0.2792 - val_accuracy: 0.9116 - val_auc: 0.9739
# Epoch 78/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2308 - accuracy: 0.9331 - auc: 0.9738 - val_loss: 0.2753 - val_accuracy: 0.9156 - val_auc: 0.9727
# Epoch 79/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2281 - accuracy: 0.9339 - auc: 0.9742 - val_loss: 0.2631 - val_accuracy: 0.9196 - val_auc: 0.9727
# Epoch 80/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2258 - accuracy: 0.9348 - auc: 0.9747 - val_loss: 0.3325 - val_accuracy: 0.8768 - val_auc: 0.9716
# Epoch 81/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2254 - accuracy: 0.9342 - auc: 0.9750 - val_loss: 0.2602 - val_accuracy: 0.9240 - val_auc: 0.9723
# Epoch 82/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2257 - accuracy: 0.9334 - auc: 0.9746 - val_loss: 0.2349 - val_accuracy: 0.9344 - val_auc: 0.9752
# Epoch 83/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2243 - accuracy: 0.9330 - auc: 0.9754 - val_loss: 0.2715 - val_accuracy: 0.9192 - val_auc: 0.9733
# Epoch 84/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2222 - accuracy: 0.9349 - auc: 0.9757 - val_loss: 0.3032 - val_accuracy: 0.9164 - val_auc: 0.9710
# Epoch 85/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2241 - accuracy: 0.9336 - auc: 0.9753 - val_loss: 0.2349 - val_accuracy: 0.9336 - val_auc: 0.9746
# Epoch 86/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2225 - accuracy: 0.9339 - auc: 0.9750 - val_loss: 0.2737 - val_accuracy: 0.9112 - val_auc: 0.9708
# Epoch 87/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2219 - accuracy: 0.9340 - auc: 0.9755 - val_loss: 0.2331 - val_accuracy: 0.9344 - val_auc: 0.9750
# Epoch 88/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2210 - accuracy: 0.9344 - auc: 0.9756 - val_loss: 0.2737 - val_accuracy: 0.9208 - val_auc: 0.9745
# Epoch 89/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2217 - accuracy: 0.9342 - auc: 0.9754 - val_loss: 0.2376 - val_accuracy: 0.9328 - val_auc: 0.9738
# Epoch 90/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2215 - accuracy: 0.9338 - auc: 0.9754 - val_loss: 0.2508 - val_accuracy: 0.9340 - val_auc: 0.9740
# Epoch 91/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2214 - accuracy: 0.9346 - auc: 0.9754 - val_loss: 0.2496 - val_accuracy: 0.9344 - val_auc: 0.9728
# Epoch 92/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2188 - accuracy: 0.9352 - auc: 0.9758 - val_loss: 0.2820 - val_accuracy: 0.9164 - val_auc: 0.9719
# Epoch 93/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2203 - accuracy: 0.9339 - auc: 0.9755 - val_loss: 0.2262 - val_accuracy: 0.9332 - val_auc: 0.9758
# Epoch 94/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2213 - accuracy: 0.9351 - auc: 0.9749 - val_loss: 0.3012 - val_accuracy: 0.9056 - val_auc: 0.9710
# Epoch 95/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2180 - accuracy: 0.9348 - auc: 0.9759 - val_loss: 0.3137 - val_accuracy: 0.8924 - val_auc: 0.9705
# Epoch 96/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2188 - accuracy: 0.9352 - auc: 0.9756 - val_loss: 0.2513 - val_accuracy: 0.9248 - val_auc: 0.9748
# Epoch 97/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2180 - accuracy: 0.9357 - auc: 0.9758 - val_loss: 0.2371 - val_accuracy: 0.9376 - val_auc: 0.9748
# Epoch 98/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2172 - accuracy: 0.9357 - auc: 0.9760 - val_loss: 0.2439 - val_accuracy: 0.9352 - val_auc: 0.9735
# Epoch 99/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2167 - accuracy: 0.9362 - auc: 0.9764 - val_loss: 0.2439 - val_accuracy: 0.9340 - val_auc: 0.9747
# Epoch 100/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2153 - accuracy: 0.9367 - auc: 0.9760 - val_loss: 0.2495 - val_accuracy: 0.9344 - val_auc: 0.9755
# Epoch 101/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2155 - accuracy: 0.9349 - auc: 0.9764 - val_loss: 0.2411 - val_accuracy: 0.9228 - val_auc: 0.9737
# Epoch 102/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2144 - accuracy: 0.9361 - auc: 0.9766 - val_loss: 0.2349 - val_accuracy: 0.9376 - val_auc: 0.9741
# Epoch 103/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2136 - accuracy: 0.9363 - auc: 0.9765 - val_loss: 0.2405 - val_accuracy: 0.9372 - val_auc: 0.9744
# Epoch 104/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2157 - accuracy: 0.9356 - auc: 0.9760 - val_loss: 0.2274 - val_accuracy: 0.9368 - val_auc: 0.9755
# Epoch 105/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2129 - accuracy: 0.9367 - auc: 0.9765 - val_loss: 0.2527 - val_accuracy: 0.9364 - val_auc: 0.9721
# Epoch 106/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2142 - accuracy: 0.9366 - auc: 0.9764 - val_loss: 0.2530 - val_accuracy: 0.9244 - val_auc: 0.9725
# Epoch 107/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2127 - accuracy: 0.9360 - auc: 0.9766 - val_loss: 0.2448 - val_accuracy: 0.9304 - val_auc: 0.9722
# Epoch 108/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2114 - accuracy: 0.9368 - auc: 0.9770 - val_loss: 0.2246 - val_accuracy: 0.9380 - val_auc: 0.9750
# Epoch 109/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2136 - accuracy: 0.9368 - auc: 0.9763 - val_loss: 0.2407 - val_accuracy: 0.9260 - val_auc: 0.9746
# Epoch 110/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2137 - accuracy: 0.9365 - auc: 0.9761 - val_loss: 0.2316 - val_accuracy: 0.9372 - val_auc: 0.9736
# Epoch 111/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2111 - accuracy: 0.9369 - auc: 0.9768 - val_loss: 0.2393 - val_accuracy: 0.9308 - val_auc: 0.9737
# Epoch 112/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2100 - accuracy: 0.9379 - auc: 0.9770 - val_loss: 0.2698 - val_accuracy: 0.9172 - val_auc: 0.9698
# Epoch 113/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2108 - accuracy: 0.9367 - auc: 0.9768 - val_loss: 0.2563 - val_accuracy: 0.9324 - val_auc: 0.9722
# Epoch 114/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2091 - accuracy: 0.9365 - auc: 0.9772 - val_loss: 0.2407 - val_accuracy: 0.9324 - val_auc: 0.9729
# Epoch 115/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2098 - accuracy: 0.9365 - auc: 0.9768 - val_loss: 0.2643 - val_accuracy: 0.9284 - val_auc: 0.9714
# Epoch 116/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2111 - accuracy: 0.9362 - auc: 0.9766 - val_loss: 0.2628 - val_accuracy: 0.9256 - val_auc: 0.9713
# Epoch 117/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2094 - accuracy: 0.9382 - auc: 0.9769 - val_loss: 0.2344 - val_accuracy: 0.9296 - val_auc: 0.9751
# Epoch 118/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2098 - accuracy: 0.9371 - auc: 0.9768 - val_loss: 0.2387 - val_accuracy: 0.9340 - val_auc: 0.9741
# Epoch 119/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2079 - accuracy: 0.9382 - auc: 0.9773 - val_loss: 0.2377 - val_accuracy: 0.9380 - val_auc: 0.9734
# Epoch 120/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2080 - accuracy: 0.9370 - auc: 0.9770 - val_loss: 0.2454 - val_accuracy: 0.9352 - val_auc: 0.9742
# Epoch 121/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2069 - accuracy: 0.9386 - auc: 0.9774 - val_loss: 0.2381 - val_accuracy: 0.9336 - val_auc: 0.9745
# Epoch 122/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2052 - accuracy: 0.9375 - auc: 0.9779 - val_loss: 0.2900 - val_accuracy: 0.9092 - val_auc: 0.9715
# Epoch 123/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2069 - accuracy: 0.9375 - auc: 0.9770 - val_loss: 0.2406 - val_accuracy: 0.9340 - val_auc: 0.9726
# Epoch 124/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2057 - accuracy: 0.9384 - auc: 0.9776 - val_loss: 0.2412 - val_accuracy: 0.9280 - val_auc: 0.9755
# Epoch 125/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2078 - accuracy: 0.9382 - auc: 0.9768 - val_loss: 0.2236 - val_accuracy: 0.9356 - val_auc: 0.9751
# Epoch 126/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2065 - accuracy: 0.9375 - auc: 0.9772 - val_loss: 0.2476 - val_accuracy: 0.9256 - val_auc: 0.9736
# Epoch 127/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2065 - accuracy: 0.9371 - auc: 0.9773 - val_loss: 0.2376 - val_accuracy: 0.9328 - val_auc: 0.9750
# Epoch 128/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2056 - accuracy: 0.9373 - auc: 0.9777 - val_loss: 0.2334 - val_accuracy: 0.9312 - val_auc: 0.9741
# Epoch 129/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2045 - accuracy: 0.9370 - auc: 0.9778 - val_loss: 0.2399 - val_accuracy: 0.9356 - val_auc: 0.9741
# Epoch 130/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2023 - accuracy: 0.9382 - auc: 0.9783 - val_loss: 0.3114 - val_accuracy: 0.8884 - val_auc: 0.9716
# Epoch 131/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2058 - accuracy: 0.9364 - auc: 0.9776 - val_loss: 0.2443 - val_accuracy: 0.9308 - val_auc: 0.9727
# Epoch 132/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2044 - accuracy: 0.9376 - auc: 0.9779 - val_loss: 0.2576 - val_accuracy: 0.9336 - val_auc: 0.9710
# Epoch 133/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2027 - accuracy: 0.9376 - auc: 0.9783 - val_loss: 0.4042 - val_accuracy: 0.8584 - val_auc: 0.9713
# Epoch 134/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2050 - accuracy: 0.9381 - auc: 0.9776 - val_loss: 0.2308 - val_accuracy: 0.9324 - val_auc: 0.9722
# Epoch 135/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2033 - accuracy: 0.9388 - auc: 0.9780 - val_loss: 0.2421 - val_accuracy: 0.9336 - val_auc: 0.9741
# Epoch 136/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2006 - accuracy: 0.9382 - auc: 0.9786 - val_loss: 0.3866 - val_accuracy: 0.8704 - val_auc: 0.9689
# Epoch 137/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.1993 - accuracy: 0.9407 - auc: 0.9782 - val_loss: 0.2348 - val_accuracy: 0.9308 - val_auc: 0.9759
# Epoch 138/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2030 - accuracy: 0.9379 - auc: 0.9780 - val_loss: 0.3161 - val_accuracy: 0.8972 - val_auc: 0.9690
# Epoch 139/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2016 - accuracy: 0.9385 - auc: 0.9780 - val_loss: 0.2424 - val_accuracy: 0.9328 - val_auc: 0.9749
# Epoch 140/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2003 - accuracy: 0.9399 - auc: 0.9784 - val_loss: 0.4068 - val_accuracy: 0.8704 - val_auc: 0.9699
# Epoch 141/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2012 - accuracy: 0.9393 - auc: 0.9779 - val_loss: 0.2301 - val_accuracy: 0.9360 - val_auc: 0.9745
# Epoch 142/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.1986 - accuracy: 0.9407 - auc: 0.9786 - val_loss: 0.2311 - val_accuracy: 0.9328 - val_auc: 0.9756
# Epoch 143/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.2008 - accuracy: 0.9384 - auc: 0.9781 - val_loss: 0.2280 - val_accuracy: 0.9308 - val_auc: 0.9748
# Epoch 144/200
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.1991 - accuracy: 0.9389 - auc: 0.9785 - val_loss: 0.2514 - val_accuracy: 0.9252 - val_auc: 0.9731
# Epoch 145/200
# 1093/1094 [============================>.] - ETA: 0s - loss: 0.1984 - accuracy: 0.9396 - auc: 0.9788Restoring model weights from the end of the best epoch: 125.
# 1094/1094 [==============================] - 20s 18ms/step - loss: 0.1983 - accuracy: 0.9397 - auc: 0.9788 - val_loss: 0.2437 - val_accuracy: 0.9332 - val_auc: 0.9746
# Epoch 145: early stopping

# %%
plt.plot(LSBG_history.history['accuracy'])
plt.plot(LSBG_history.history['val_accuracy'])
plt.title('LSBG Detector Accuracy')
plt.ylabel('Accuracy for LSBG Detector')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='lower right')
plt.show()
# summarize history for loss
plt.plot(LSBG_history.history['loss'])
plt.plot(LSBG_history.history['val_loss'])
plt.title('LSBG_Detector Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()

# %% [markdown]
# ## Testing the LSBG DETR Model on the Test Data

# %%
# Make predictions on the test set using the 'LSBG_Detector' model
X_test_pred = LSBG_Detector.predict(X_test)

# Calculate the ROC curve and get the False Positive Rate (frp), True Positive Rate (tpr), and Threshold (thr)
frp_transformer, tpr_transformer, thr_transformer = roc_curve(Y_test, X_test_pred)

# Plot the ROC curve for the 'LSBG Detector'
plt.plot(frp_transformer, tpr_transformer, label='LSBG Detector')
plt.xlim(0, 1)
plt.ylim(0, 1)
plt.legend(loc=4)
plt.xlabel('FPR (False Positive Rate)')
plt.ylabel('TPR (True Positive Rate)')
plt.title('ROC (Receiver Operating Characteristic) evaluated on Testing set')
plt.grid(True)  # Show grid lines on the plot
plt.show()

# Calculate and print the Area Under the ROC Curve (AUC)
print('The area under the ROC curve is', roc_auc_score(Y_test, X_test_pred))

# Evaluate the 'LSBG_Detector' model on the test set and print the results
LSBG_Detector.evaluate(X_test, Y_test, batch_size=128, verbose=1)
# Out:
# The area under the ROC curve is  0.9829170909657642
# 20/20 [==============================] - 1s 26ms/step - loss: 0.1841 - accuracy: 0.9436 - auc: 0.9827
# [0.18405961990356445, 0.9436165690422058, 0.9826562404632568]

# %% [markdown]
# ### Checking the prediction probability

# %%
# Create a new figure with a specific size
plt.figure(figsize=(10, 10))

# Plot histograms for predicted probabilities of 'LSBGs' (label 1) and 'Artifacts' (label 0)
# Set the range, number of bins, colors, transparency, density, and labels
plt.hist(X_test_pred[Y_test == 1], range=[0, 1], bins=50, color='mediumblue', alpha=0.6, density=False, label='LSBGs')
plt.hist(X_test_pred[Y_test == 0], range=[0, 1], bins=50, color='red', alpha=0.6, density=False, label='Artifacts')

# Add grid lines
plt.grid(ls='--', alpha=0.6)

# Adjust tick label sizes
plt.tick_params(axis='both', labelsize=12)

# Add legend with frame, location, and font size
plt.legend(frameon=True, loc='upper center', fontsize=17)

# Set the x-axis label and y-axis label, and title for the plot
plt.xlabel("Output Probability", fontsize=15.5)
plt.ylabel("Number of Examples", fontsize=15.5)
plt.title("Probability distribution predicted by the model", fontsize=18)

# Ensure a tight layout
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ### Confusion Matrix

# %%
# Initialize an empty list to store Transformer results
Transformer_Result = []

# Loop through the predicted probabilities (X_test_pred) for each example in the test set
for i in range(0, len(X_test_pred)):
    if X_test_pred[i] > 0.6:
        y = 1  # Assign 1 if predicted probability is greater than 0.6
    if X_test_pred[i] < 0.6:
        y = 0  # Assign 0 if predicted probability is less than 0.6
    Transformer_Result.append(y)  # Append the result to the list

# Calculate and print the accuracy of the model
print("The Accuracy of the model is", accuracy_score(Y_test, Transformer_Result))

# Generate and print a classification report
print(classification_report(Y_test, Transformer_Result))

# Generate and print a confusion matrix
print(confusion_matrix(Y_test, Transformer_Result))

# Plot a normalized confusion matrix
skplt.metrics.plot_confusion_matrix(Y_test, Transformer_Result, normalize=True)
plt.show()
# Out:
# The Accuracy of the model is  0.9436165928312525
#               precision    recall  f1-score   support
#
#            0       0.95      0.91      0.93      1077
#            1       0.94      0.97      0.95      1406
#
#     accuracy                           0.94      2483
#    macro avg       0.95      0.94      0.94      2483
# weighted avg       0.94      0.94      0.94      2483
#
# [[ 985   92]
#  [  48 1358]]

# %%
# Save the weights of the 'LSBG_Detector' model to a file
# Replace '............................/LSBG_Vision' with the actual file path where you want to save the weights
LSBG_Detector.save_weights(r'............................/LSBG_DETR', overwrite=True)

# %% [markdown]
# ### Using the model
#
# Compile the model as shown above. After compiling the model load the trained weights to the compiled model.

# %%
# Load the weights into the 'LSBG_Detector' model from a file
# Replace '............................/LSBG_Vision' with the actual file path where the model weights are stored
LSBG_Detector.load_weights(r'............................/LSBG_Vision')
